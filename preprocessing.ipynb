# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler
import pickle

# %%
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
df.set_index('timestamp', inplace=True)
df.head()
# Out:
#             Asset_ID  Count        Open        High         Low       Close  \
# timestamp
# 1514764860         2   40.0   2376.5800   2399.5000   2357.1400   2374.5900
# 1514764860         0    5.0      8.5300      8.5300      8.5300      8.5300
# 1514764860         1  229.0  13835.1940  14013.8000  13666.1100  13850.1760
# 1514764860         5   32.0      7.6596      7.6596      7.6567      7.6576
# 1514764860         7    5.0     25.9200     25.9200     25.8740     25.8770
#
#                  Volume          VWAP    Target
# timestamp
# 1514764860    19.233005   2373.116392 -0.004218
# 1514764860    78.380000      8.530000 -0.014399
# 1514764860    31.550062  13827.062093 -0.014643
# 1514764860  6626.713370      7.657713 -0.013922
# 1514764860   121.087310     25.891363 -0.008264

# %%
asset_details = pd.read_csv('data/asset_details.csv')
asset_details.sort_values('Asset_ID')
# Out:
#     Asset_ID    Weight        Asset_Name
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 0          2  2.397895      Bitcoin Cash
# 10         3  4.406719           Cardano
# 13         4  3.555348          Dogecoin
# 3          5  1.386294            EOS.IO
# 5          6  5.894403          Ethereum
# 4          7  2.079442  Ethereum Classic
# 11         8  1.098612              IOTA
# 6          9  2.397895          Litecoin
# 12        10  1.098612             Maker
# 7         11  1.609438            Monero
# 9         12  2.079442           Stellar
# 8         13  1.791759              TRON

# %%
# we reindex to fill the missing timestamps

# %%
binance = df[df['Asset_ID']==0]
print(f"number of rows before reindexing : {binance.shape[0]}")
binance = binance.reindex(range(binance.index[0], binance.index[-1]+60, 60), method='pad')
print(f"number of rows after reindexing : {binance.shape[0]}")
# Out:
# number of rows before reindexing : 1942619
# number of rows after reindexing : 1956960

# %%
def log_returns(serie):
    return np.log(serie).diff(periods=15)

# %%
binance['log_returns'] = log_returns(binance['Close']).shift(-16).fillna(0)
binance[['Target','log_returns']]
# Out:
#               Target  log_returns
# timestamp
# 1514764860 -0.014399    -0.014504
# 1514764920 -0.015875    -0.016003
# 1514764980 -0.015410    -0.015530
# 1514765040 -0.012524    -0.012603
# 1514765100 -0.005940    -0.005958
# ...              ...          ...
# 1632182160       NaN     0.000000
# 1632182220       NaN     0.000000
# 1632182280       NaN     0.000000
# 1632182340       NaN     0.000000
# 1632182400       NaN     0.000000
#
# [1956960 rows x 2 columns]

# %%
binance['Target'].fillna(binance['log_returns'], inplace=True)
binance['Target']
# Out:
# timestamp
# 1514764860   -0.014399
# 1514764920   -0.015875
# 1514764980   -0.015410
# 1514765040   -0.012524
# 1514765100   -0.005940
#                 ...
# 1632182160    0.000000
# 1632182220    0.000000
# 1632182280    0.000000
# 1632182340    0.000000
# 1632182400    0.000000
# Name: Target, Length: 1956960, dtype: float64

# %%
binance.head()
# Out:
#             Asset_ID  Count    Open    High     Low   Close   Volume  \
# timestamp
# 1514764860         0    5.0  8.5300  8.5300  8.5300  8.5300    78.38
# 1514764920         0    7.0  8.5300  8.5300  8.5145  8.5145    71.39
# 1514764980         0   45.0  8.5065  8.5299  8.4848  8.4848  1546.82
# 1514765040         0   14.0  8.5009  8.5066  8.4744  8.5009   125.80
# 1514765100         0    5.0  8.5007  8.5007  8.4560  8.4560   125.01
#
#                 VWAP    Target  log_returns
# timestamp
# 1514764860  8.530000 -0.014399    -0.014504
# 1514764920  8.520215 -0.015875    -0.016003
# 1514764980  8.501394 -0.015410    -0.015530
# 1514765040  8.479810 -0.012524    -0.012603
# 1514765100  8.458435 -0.005940    -0.005958

# %%
binance['_Spread'] = binance['Open'] - binance['Close']
binance['_Max_spread'] = binance['High'] - binance['Low']

# %%
X = binance[['Count','Volume','_Spread','_Max_spread']]
y = binance.Target

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), index=X.index, columns=X.columns)

# %%
X_scaled.head()
# Out:
#                Count    Volume   _Spread  _Max_spread
# timestamp
# 1514764860 -0.413922 -0.612800 -0.000519    -0.333829
# 1514764920 -0.409329 -0.615214  0.050954    -0.308071
# 1514764980 -0.322069 -0.105676  0.071543    -0.258881
# 1514765040 -0.393255 -0.596424 -0.000519    -0.280319
# 1514765100 -0.413922 -0.596697  0.147923    -0.259546

# %%
pickle.dump(X_scaled, open( "X_scaled.pickle", "wb" ) )
